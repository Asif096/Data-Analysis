# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# # Line Plot

# %%
x = range(1, 10)
y = [1, 2, 3, 4, 0, 4, 3, 2, 1]

plt.plot(x, y)

# %% [markdown]
# # Line chart from pandas object

# %%
cars = pd.read_csv('C:/Users\moham\Jupyter Practice\Exercise Files\Data\mtcars.csv')
cars.columns = ['car_names', 'mpg', 'cylinders', 'displacement', 'hp', 'drat', 'wt', 'wsec', 'vs', 'am', 'gear', 'carb']

mpg = cars['mpg']

# %%
mpg.plot()

# %%
df = cars[['cylinders', 'wt', 'mpg']]
df.plot()

# %% [markdown]
# # bar chart

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %%
mpg.plot(kind="bar")

# %%
mpg.plot(kind="barh")

# %%
x = [1, 2, 3, 4, 0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# # saving a plot

# %%
mpg.plot(kind='pie')
plt.savefig('pie chart.png')
plt.show()
